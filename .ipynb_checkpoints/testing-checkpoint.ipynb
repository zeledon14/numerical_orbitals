# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import os
plt.rcParams["figure.figsize"] = (25,10)

plt.rcParams.update({'font.size': 22})

colors='bgrykcm'
symbol='*-+^'

# %%
from Differential_Problem_Testing import DP_testing

from Integrators import RK4

from Integrators import predictor_corrector_RK4_Adams_Moulton4 as PC

grid= np.linspace(-4.8, 4.8, num=300) + 0.001


u_og=np.exp(-1.0*grid**2.0)

# %%
plt.plot(grid,u_og,'r*')
plt.show()

# %%
h_arra= grid[1:] - grid[:-1]

y1=u_og[0]
y2=((u_og[1]-u_og[0])/h_arra[0])

y_arra=[[y1],[y2]]
DP= DP_testing(grid, y_arra)
y_rk= RK4(DP)

y_arra=[[y1],[y2]]
DP= DP_testing(grid, y_arra)
y_pc= PC(DP)

# %%
plt.plot(grid,y_rk[0],'r*', grid,y_pc[0],'g+', grid,u_og,'b-')
plt.show()

# %%
grid[:5]
# Out:
# array([-4.799     , -4.76689298, -4.73478595, -4.70267893, -4.67057191])

# %%
from Differential_Function import df1_get_k_for_rk4, df2_get_k_for_rk4

# %%
from Integrators import RK4

# %%
grid= np.linspace(-4.8, 4.8, num=300) + 0.001

# %%
u_og=np.exp(-1.0*grid**2.0)

# %%
plt.plot(grid,u_og,'r*')
plt.show()

# %%
h_arra= grid[1:] - grid[:-1]

# %%
y1=u_og[0]
y2=((u_og[1]-u_og[0])/h_arra[0])

# %%
y_init_values=[y1,y2]

# %%
y= RK4(y_init_values, grid, [df1_get_k_for_rk4, df2_get_k_for_rk4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-549d62195da1> in <module>
# ----> 1 y= RK4(y_init_values, grid, [df1_get_k_for_rk4, df2_get_k_for_rk4])
#
# ~/Desktop/physics_coding_projects/python/numerical_orbitals/Integrators.py in RK4(y_init, grid, functions, forward)
#      49         #make next step in the solution
#      50         for m in range(numb):
# ---> 51             y_arra[m].append(y_arra[m][i] (1.0/6.0)*(k[0,m] + 2.0*k[1,m] + 2.0*k[2,m] + k[3,m]))
#      52     return np.array(y_arra)
#
# TypeError: 'numpy.float64' object is not callable

# %%
def F1(argu):
    if

# %%
u=

# %%
h_arra
# Out:
# array([0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
#        0.03210702, 0.03210702, 0.03210702, 0.03210702, 0.03210702,
# ...

# %%
from Atomic_Like_Potential import V_coulomb
from Atomic_Like_Potential import V_angular

# %%
param={'Z'=1.0, 'l'=0.0}

# %%
#debuging ends

# %%
plt.plot(exp_grid,np.array(u_func_norm)**2,'r*', exp_grid,np.array(u_hydr_norm)**2,'b^')
plt.show()

# %%
#testing with known answer for hydrogen ends
